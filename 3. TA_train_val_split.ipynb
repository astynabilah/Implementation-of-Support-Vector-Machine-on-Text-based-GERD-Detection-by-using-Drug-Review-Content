# %%
import numpy as np
import pandas as pd
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
downloaded = drive.CreateFile({'id':"1bCp5zYgIN4vet-NnbRiuD64RSOEWo0NE"})
downloaded.GetContentFile('train.csv') 
train = pd.read_csv('train.csv') 
downloaded = drive.CreateFile({'id':"1ZDTPRJjZgOdkFOngjuN7RKd8-PMWCTnx"})
downloaded.GetContentFile('test.csv') 
test = pd.read_csv('test.csv') 
train = train.drop(str(train.columns[0]),axis=1)
test = test.drop(str(test.columns[0]),axis=1)

# %%
x_train = train['review']
y_train = train['condition']
x_test = test['review']
y_test = test['condition']

# %%
from sklearn.model_selection import train_test_split
x_train, x_validation, y_train, y_validation = train_test_split(x_train, y_train, test_size=0.3)

# %%
x_train
# Out:
# 270    dentist prescribe really rough wisdom tooth re...
# 529      issue every day almost issue notice side effect
# 517    medication mg x daily chest pain shortness bre...
# 808    start take medication migraine yesterday altho...
# 970    work admirably immediate control reflux sympto...
#                              ...
# 156    medicine okay certainly get rid paranoid thoug...
# 903    make long story short miss year quality time c...
# 662    im diagnose bipolar disorder psychotic feature...
# 912    ive use week far skin seem peel burn however c...
# 320    get vilolently sick vomit migraine stomach cra...
# Name: review, Length: 694, dtype: object

# %%
x_validation
# Out:
# 814    struggle acne half life try counter remedy ben...
# 494    nutshell even though want drug work hate take ...
# 887    intense pain along bottom rib second round car...
# 426    sooo im unwillingly pretty prone yi didnt opti...
# 642    personally terrible experience dexilant acid r...
#                              ...
# 658    start take loseasonique live busy lifestyle qu...
# 843    stuff really awful within week tear bicep hand...
# 292    va prescribe medication use year find excessiv...
# 539    side effect increase time arrythmia chest pain...
# 435    three year ago go doctor get severely ill ever...
# Name: review, Length: 298, dtype: object

# %%
train_new = pd.concat([x_train, y_train], axis=1).reset_index()
val_new = pd.concat([x_validation, y_validation], axis=1).reset_index()

# %%
train_new
# Out:
#      index                                             review  condition
# 0      270  dentist prescribe really rough wisdom tooth re...          0
# 1      529    issue every day almost issue notice side effect          1
# 2      517  medication mg x daily chest pain shortness bre...          1
# 3      808  start take medication migraine yesterday altho...          0
# 4      970  work admirably immediate control reflux sympto...          1
# ..     ...                                                ...        ...
# 689    156  medicine okay certainly get rid paranoid thoug...          0
# 690    903  make long story short miss year quality time c...          0
# 691    662  im diagnose bipolar disorder psychotic feature...          0
# 692    912  ive use week far skin seem peel burn however c...          0
# 693    320  get vilolently sick vomit migraine stomach cra...          0
#
# [694 rows x 3 columns]

# %%
val_new
# Out:
#      index                                             review  condition
# 0      814  struggle acne half life try counter remedy ben...          0
# 1      494  nutshell even though want drug work hate take ...          0
# 2      887  intense pain along bottom rib second round car...          1
# 3      426  sooo im unwillingly pretty prone yi didnt opti...          0
# 4      642  personally terrible experience dexilant acid r...          1
# ..     ...                                                ...        ...
# 293    658  start take loseasonique live busy lifestyle qu...          0
# 294    843  stuff really awful within week tear bicep hand...          1
# 295    292  va prescribe medication use year find excessiv...          1
# 296    539  side effect increase time arrythmia chest pain...          1
# 297    435  three year ago go doctor get severely ill ever...          1
#
# [298 rows x 3 columns]

# %%
from google.colab import files
train_new.to_csv('train_data.csv')
files.download('train_data.csv')

val_new.to_csv('validation_data.csv')
files.download('validation_data.csv')
